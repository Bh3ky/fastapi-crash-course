# %% [markdown]
# # Path Parameters
#
# - we can declare path "parameters" or "variables" with the same syntax used by Python format strings.

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/items/{item_id}")
async def read_item(item_id):
    return {"item_id": item_id}

# we can also declare path parameters with type:
# Out:
# Running cells with 'venv (Python 3.13.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/telasi/Developer/FastAPI/venv/bin/python -m pip install ipykernel -U --force-reinstall'
